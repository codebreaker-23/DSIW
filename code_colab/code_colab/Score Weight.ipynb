# %%
# Weights for each age category
age_weights = {
    '28 and younger': {
        'Quality of the neighborhood': 0.308108108,
        'Convenient to job': 0.383783784,
        'Overall affordability of homes': 0.308108108
    },
    '29 to 38': {
        'Quality of the neighborhood': 0.375,
        'Convenient to job': 0.363095238,
        'Overall affordability of homes':0.261904762
    },
    '39 to 53': {
        'Quality of the neighborhood': 0.416666667,
        'Convenient to job': 0.333333333,
        'Overall affordability of homes': 0.25
    },
    '54 to 63': {
        'Quality of the neighborhood': 0.440944882,
        'Convenient to job': 0.283464567,
        'Overall affordability of homes': 0.275590551
    },
    '64 to 72': {
        'Quality of the neighborhood': 0.541666667,
        'Convenient to job': 0.09375,
        'Overall affordability of homes': 0.364583333
    },
    '73 to 93': {
        'Quality of the neighborhood': 0.555555556,
        'Convenient to job': 0.037037037,
        'Overall affordability of homes': 0.407407407
    }
}

# %%
# User input
user_age_category = '' # Select your age group'28 and younger', '29 to 38', '39 to 53', '54 to 63', '64 to 72', '73 to 93'

# %%
# Access individual weights
weights = age_weights[user_age_category]
quality_of_neighborhood_weight = weights['Quality of the neighborhood']
convenient_to_job_weight = weights['Convenient to job']
overall_affordability_weight = weights['Overall affordability of homes']
